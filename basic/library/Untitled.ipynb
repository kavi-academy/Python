# %% [markdown]
# # Library

# %% [markdown]
# ## Pandas

# %%
import pandas as pd

# %%
employee=pd.read_csv("data.csv")
employee
# Out:
#    Employee_ID     Name Department  Age  Salary  Performance_Score   Join_Date
# 0          101    Alice         HR   25   50000                4.2  2021-03-15
# 1          102      Bob         IT   30   75000                3.8  2019-06-20
# 2          103  Charlie         IT   45  110000                4.9  2015-01-10
# 3          104    David    Finance   35   90000                4.5  2018-11-05
# 4          105      Eva         HR   28   55000                3.9  2022-08-01
# 5          106    Frank    Finance   40   85000                4.1  2017-04-12
# 6          107    Grace         IT   32   82000                4.7  2020-09-30
# 7          108   Hannah         HR   50   95000                4.6  2012-05-18

# %% [markdown]
# ## Numpy

# %%
import numpy as np

# %%
np.repeat(a = employee, repeats= 2, axis=0)
# Out:
# array([[101, 'Alice', 'HR', 25, 50000, 4.2, '2021-03-15'],
#        [101, 'Alice', 'HR', 25, 50000, 4.2, '2021-03-15'],
#        [102, 'Bob', 'IT', 30, 75000, 3.8, '2019-06-20'],
#        [102, 'Bob', 'IT', 30, 75000, 3.8, '2019-06-20'],
#        [103, 'Charlie', 'IT', 45, 110000, 4.9, '2015-01-10'],
#        [103, 'Charlie', 'IT', 45, 110000, 4.9, '2015-01-10'],
#        [104, 'David', 'Finance', 35, 90000, 4.5, '2018-11-05'],
#        [104, 'David', 'Finance', 35, 90000, 4.5, '2018-11-05'],
#        [105, 'Eva', 'HR', 28, 55000, 3.9, '2022-08-01'],
#        [105, 'Eva', 'HR', 28, 55000, 3.9, '2022-08-01'],
#        [106, 'Frank', 'Finance', 40, 85000, 4.1, '2017-04-12'],
#        [106, 'Frank', 'Finance', 40, 85000, 4.1, '2017-04-12'],
#        [107, 'Grace', 'IT', 32, 82000, 4.7, '2020-09-30'],
#        [107, 'Grace', 'IT', 32, 82000, 4.7, '2020-09-30'],
#        [108, 'Hannah', 'HR', 50, 95000, 4.6, '2012-05-18'],
# ...

# %%
employee_updated = pd.DataFrame(data=np.repeat(a=employee, repeats=2, axis=0))
employee_updated
# Out:
#       0        1        2   3       4    5           6
# 0   101    Alice       HR  25   50000  4.2  2021-03-15
# 1   101    Alice       HR  25   50000  4.2  2021-03-15
# 2   102      Bob       IT  30   75000  3.8  2019-06-20
# 3   102      Bob       IT  30   75000  3.8  2019-06-20
# 4   103  Charlie       IT  45  110000  4.9  2015-01-10
# 5   103  Charlie       IT  45  110000  4.9  2015-01-10
# 6   104    David  Finance  35   90000  4.5  2018-11-05
# 7   104    David  Finance  35   90000  4.5  2018-11-05
# 8   105      Eva       HR  28   55000  3.9  2022-08-01
# 9   105      Eva       HR  28   55000  3.9  2022-08-01
# 10  106    Frank  Finance  40   85000  4.1  2017-04-12
# 11  106    Frank  Finance  40   85000  4.1  2017-04-12
# 12  107    Grace       IT  32   82000  4.7  2020-09-30
# 13  107    Grace       IT  32   82000  4.7  2020-09-30
# 14  108   Hannah       HR  50   95000  4.6  2012-05-18
# 15  108   Hannah       HR  50   95000  4.6  2012-05-18

# %% [markdown]
# ## Matplotlib

# %% [markdown]
# ### Data Types
# 1. Discrete - Countable, it will nver have any units, you can't measure it
# 2. Continous - It will have units, it is measurable

# %%
from matplotlib import pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#      ---------------------------------------- 0.1/8.2 MB 2.6 MB/s eta 0:00:04
#       --------------------------------------- 0.2/8.2 MB 2.1 MB/s eta 0:00:04
#      - -------------------------------------- 0.3/8.2 MB 2.6 MB/s eta 0:00:03
#      -- ------------------------------------- 0.5/8.2 MB 2.9 MB/s eta 0:00:03
#      --- ------------------------------------ 0.7/8.2 MB 3.1 MB/s eta 0:00:03
#      ---- ----------------------------------- 0.9/8.2 MB 3.4 MB/s eta 0:00:03
#      ----- ---------------------------------- 1.1/8.2 MB 3.6 MB/s eta 0:00:02
#      ------ --------------------------------- 1.3/8.2 MB 3.7 MB/s eta 0:00:02
#      ------- -------------------------------- 1.5/8.2 MB 3.9 MB/s eta 0:00:02
#      -------- ------------------------------- 1.7/8.2 MB 3.8 MB/s eta 0:00:02
#      --------- ------------------------------ 2.0/8.2 MB 3.9 MB/s eta 0:00:02
# ...

# %%
plt.hist(x = employee['Salary'])
# Out:
# (array([2., 0., 0., 0., 1., 2., 1., 1., 0., 1.]),
#  array([ 50000.,  56000.,  62000.,  68000.,  74000.,  80000.,  86000.,
#          92000.,  98000., 104000., 110000.]),
#  <BarContainer object of 10 artists>)
