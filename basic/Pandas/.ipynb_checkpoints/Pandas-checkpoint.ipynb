# %% [markdown]
# ## 1. know your data
# 1. business understannding
# 2. data collection
# 3. data understanding
# 4. data prepration(cleaning)

# %%
import pandas as pd
pd.read_csv(filepath_or_buffer="Insurance.csv")
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
pd.read_csv(filepath_or_buffer="data.tsv.txt",sep="\t")
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
hotel_order=pd.read_table(filepath_or_buffer="data.tsv.txt")
hotel_order
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
pd.read_table(filepath_or_buffer="Insurance.csv",sep=",")
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ## Initial Analysis of Data

# %%
hotel_order.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 hotel_order.shape()
#
# TypeError: 'tuple' object is not callable

# %%
hotel_order.shape
# Out:
# (4622, 5)

# %% [markdown]
# ### Function use ()
# ### Attribute dosen't use bracket
# ## Terminology:
# 1. rows - Observation/Records
# 2. column - Parameter/Features

# %%
hotel_order.isnull().sum() #chain of functions
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
hotel_order.describe() #Generate descriptive statistics. by default use only numeric
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
hotel_order.dtypes #(In pandas string is called as "object")
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
hotel_order.describe(include="all") #added to include all int, object, float, etc
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %% [markdown]
# ## Find out the items sold in hotel

# %%
hotel_order.nunique()
# Out:
# order_id              1834
# quantity                 9
# item_name               50
# choice_description    1043
# item_price              78
# dtype: int64

# %%
print(hotel_order["item_name"].unique())
# Out:
# ['Chips and Fresh Tomato Salsa' 'Izze' 'Nantucket Nectar'
#  'Chips and Tomatillo-Green Chili Salsa' 'Chicken Bowl' 'Side of Chips'
#  'Steak Burrito' 'Steak Soft Tacos' 'Chips and Guacamole'
#  'Chicken Crispy Tacos' 'Chicken Soft Tacos' 'Chicken Burrito'
#  'Canned Soda' 'Barbacoa Burrito' 'Carnitas Burrito' 'Carnitas Bowl'
#  'Bottled Water' 'Chips and Tomatillo Green Chili Salsa' 'Barbacoa Bowl'
#  'Chips' 'Chicken Salad Bowl' 'Steak Bowl' 'Barbacoa Soft Tacos'
#  'Veggie Burrito' 'Veggie Bowl' 'Steak Crispy Tacos'
#  'Chips and Tomatillo Red Chili Salsa' 'Barbacoa Crispy Tacos'
#  'Veggie Salad Bowl' 'Chips and Roasted Chili-Corn Salsa'
#  'Chips and Roasted Chili Corn Salsa' 'Carnitas Soft Tacos'
#  'Chicken Salad' 'Canned Soft Drink' 'Steak Salad Bowl'
#  '6 Pack Soft Drink' 'Chips and Tomatillo-Red Chili Salsa' 'Bowl'
#  'Burrito' 'Crispy Tacos' 'Carnitas Crispy Tacos' 'Steak Salad'
#  'Chips and Mild Fresh Tomato Salsa' 'Veggie Soft Tacos'
# ...

# %% [markdown]
# ### Give me the list of top 5 sellings items

# %%
hotel_order.groupby(by="item_name")["quantity"].sum().sort_values(ascending=False).head(5)
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Steak Burrito          386
# Canned Soft Drink      351
# Name: quantity, dtype: int64

# %%
## Give me the list of Least 5 sellings items
hotel_order.groupby(by="item_name")["quantity"].sum().sort_values().head()
# Out:
# item_name
# Carnitas Salad                       1
# Chips and Mild Fresh Tomato Salsa    1
# Veggie Crispy Tacos                  1
# Crispy Tacos                         2
# Salad                                2
# Name: quantity, dtype: int64

# %% [markdown]
# ## 2. Data cleaning

# %%
hotel_order.dtypes #item_price has dollar associted with it so it is Object datatype
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
hotel_order["item_price"].replace(to_replace="$",value="")# pandas replace not working
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
hotel_order["item_price"].str.replace(old="$",old="")
# Out:
#   Cell In[44], line 1
#     hotel_order["item_price"].str.replace(old="$",old="")
#                                                   ^
# SyntaxError: keyword argument repeated: old

# %%
hotel_order["item_price"].str.replace("$","")
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#          ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: object

# %%
hotel_order["item_price"].str.replace("$","").float
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8208\611496461.py in ?()
# ----> 1 hotel_order["item_price"].str.replace("$","").float
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'float'

# %%
hotel_order["item_price"].str.replace("$","").astype(float) #chain of method
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
hotel_order.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
hotel_order["item_price"] = hotel_order["item_price"].str.replace("$","").astype(float) #chain of method

# %%
hotel_order.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
hotel_order.describe()
# Out:
#           order_id     quantity   item_price
# count  4622.000000  4622.000000  4622.000000
# mean    927.254868     1.075725     7.464336
# std     528.890796     0.410186     4.245557
# min       1.000000     1.000000     1.090000
# 25%     477.250000     1.000000     3.390000
# 50%     926.000000     1.000000     8.750000
# 75%    1393.000000     1.000000     9.250000
# max    1834.000000    15.000000    44.250000

# %% [markdown]
# ## Task 1
# 1. Findout the top selling items individual revenue it made
# 2. total revenue of the top 2 items sold
# 3. find atleast 2 more questions on the same dataset

# %%
hotel_order["item_price"] = hotel_order["item_price"]*hotel_order["quantity"]

# %%
hotel_order.groupby(by="item_name")["item_price"].sum().sort_values(ascending=False).head(5)
# Out:
# item_name
# Chicken Bowl           8044.63
# Chicken Burrito        6387.06
# Steak Burrito          4236.13
# Steak Bowl             2479.81
# Chips and Guacamole    2475.62
# Name: item_price, dtype: float64

# %%
total_revenue_top2=hotel_order.groupby(by="item_name")["item_price"].sum().sort_values(ascending=False).head(2).sum()
total_revenue_top2
# Out:
# np.float64(14431.69)

# %% [markdown]
# # 3 Pandas data structure
# 1. 1D - Series
# 2. 2D - DataFrame

# %%
pd.Series(data=1)
# Out:
# 0    1
# dtype: int64

# %%
pd.Series(data=[1,2])
# Out:
# 0    1
# 1    2
# dtype: int64

# %%
pd.Series(data=[1,2,5.6,'$5.6'])
# Out:
# 0       1
# 1       2
# 2     5.6
# 3    $5.6
# dtype: object

# %%
pd.DataFrame(data=[1,2,5.6,'$5.6'])
# Out:
#       0
# 0     1
# 1     2
# 2   5.6
# 3  $5.6

# %%
pd.DataFrame(data={"amount":[1,2,5.6],"item_name":["chocolate","pencil","eraser"]})
# Out:
#    amount  item_name
# 0     1.0  chocolate
# 1     2.0     pencil
# 2     5.6     eraser

# %% [markdown]
# ## 4 Filtering, selecting, sorting

# %%
football_data = pd.read_csv("Euro_2012_stats_TEAM.csv")

# %%
# pd.set_option('display.max_column',None) # display all columns in Juypter Notebook

# %%
football_data
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
filter_fb_data = football_data[["Team","Goals","Yellow Cards","Red Cards"]] # first '[' is filteration, second '[' - more than one column use second square bracket

# %%
filter_fb_data
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 0               Croatia      4             9          0
# 1        Czech Republic      4             7          0
# 2               Denmark      4             4          0
# 3               England      5             5          0
# 4                France      3             6          0
# 5               Germany     10             4          0
# 6                Greece      5             9          1
# 7                 Italy      6            16          0
# 8           Netherlands      2             5          0
# 9                Poland      2             7          1
# 10             Portugal      6            12          0
# 11  Republic of Ireland      1             6          1
# 12               Russia      5             6          0
# 13                Spain     12            11          0
# 14               Sweden      5             7          0
# 15              Ukraine      2             5          0

# %%
filter_fb_data.sort_values(by="Yellow Cards",ascending=False)
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 7                 Italy      6            16          0
# 10             Portugal      6            12          0
# 13                Spain     12            11          0
# 0               Croatia      4             9          0
# 6                Greece      5             9          1
# 14               Sweden      5             7          0
# 9                Poland      2             7          1
# 1        Czech Republic      4             7          0
# 12               Russia      5             6          0
# 11  Republic of Ireland      1             6          1
# 4                France      3             6          0
# 3               England      5             5          0
# 8           Netherlands      2             5          0
# 15              Ukraine      2             5          0
# 5               Germany     10             4          0
# 2               Denmark      4             4          0

# %%
filter_fb_data[filter_fb_data["Red Cards"] == 1]
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 6                Greece      5             9          1
# 9                Poland      2             7          1
# 11  Republic of Ireland      1             6          1

# %%
filter_fb_data[filter_fb_data["Yellow Cards"] >= 8]
# Out:
#         Team  Goals  Yellow Cards  Red Cards
# 0    Croatia      4             9          0
# 6     Greece      5             9          1
# 7      Italy      6            16          0
# 10  Portugal      6            12          0
# 13     Spain     12            11          0

# %% [markdown]
# ## How to deal with missing values

# %%
pd.read_csv("Employee_data.csv")
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 1    Nasir  31.0    IT Tech      NaN  12-11-2020
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 6      NaN  40.0         IT  64000.0  10-09-2022
# 7    Nasir  31.0    IT Tech      NaN  12-11-2020
