# %%
print("HI")
# Out:
# HI

# %%
print("HELLO")
# Out:
# HELLO

# %% [markdown]
# ## Task1

# %%
learner1="krishnamoorthy"
learner1.count("y")
# Out:
# 1

# %%
first_name = input("First name:")
second_name = input("Second name")
print(f"Your first name is: {first_name} and Your second name is: {second_name}")
# Out:
# First name: kavi
# Second name rasu
# Your first name is: kavi and Your second name is: rasu

# %% [markdown]
# ## find th factor of number

# %%
num = int(input("enter the number to find its factor"))
factors=[]
for i in range(1,num+1):
    if 20%i == 0:
        factors.append(i)

print(f'Factors of {num} is {factors}')
# Out:
# enter the number to find its factor 20
# Factors of 20 is [1, 2, 4, 5, 10, 20]
